# %%
# Import the necessary libaries
import pandas as pd
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer
from datasets import load_dataset

# %%
ds = load_dataset("KisanVaani/agriculture-qa-english-only")
print(ds["train"][0])
# Out:
# {'question': 'why is crop rotation important in farming?', 'answers': 'This helps to prevent soil erosion and depletion, and can also help to control pests and diseases'}

# %%
# Extract questions and answers

questions = [item['question'] for item in ds['train']]
answers = [item['answers'] for item in ds['train']]


# Tokenize the data to convert a text in a model friendly format.
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def preprocess_data(examples):
    inputs = tokenizer(examples['question'], padding="max_length", truncation=True, max_length=128)
    targets = tokenizer(examples['answers'], padding="max_length", truncation=True, max_length=128)
    return {"input_ids": inputs["input_ids"], "attention_mask": inputs["attention_mask"], "labels": targets["input_ids"]}

ds = ds.map(preprocess_data, batched=True)

# %%
# Fine tune a transformer model

from transformers import TFAutoModelForSeq2SeqLM, DataCollatorForSeq2Seq

model = TFAutoModelForSeq2SeqLM.from_pretrained("t5-small")
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
train_dataset = ds["train"].shuffle().select(range(10000))  # Reduce size if needed
train_dataset = train_dataset.to_tf_dataset(
    columns=["input_ids", "attention_mask"],
    label_cols=["labels"],
    batch_size=8,
    shuffle=True,
    collate_fn=data_collator
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer)

# Train the model
model.fit(train_dataset, epochs=3)
# Out:
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\datasets\arrow_dataset.py:405: FutureWarning: The output of `to_tf_dataset` will change when a passing single element list for `labels` or `columns` in the next datasets version. To return a tuple structure rather than dict, pass a single string.
# Old behaviour: columns=['a'], labels=['labels'] -> (tf.Tensor, tf.Tensor)
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
# New behaviour: columns=['a'],labels=['labels'] -> ({'a': tf.Tensor}, {'labels': tf.Tensor})
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[67], line 8
#       6 data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
#       7 train_dataset = ds["train"].shuffle().select(range(10000))  # Reduce size if needed
# ----> 8 train_dataset = train_dataset.to_tf_dataset(
#       9     columns=["input_ids", "attention_mask"],
#      10     label_cols=["labels"],
#      11     batch_size=8,
#      12     shuffle=True,
#      13     collate_fn=data_collator
#      14 )
#      16 optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
#      17 model.compile(optimizer=optimizer)
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\datasets\arrow_dataset.py:454, in TensorflowDatasetMixin.to_tf_dataset(self, batch_size, columns, shuffle, collate_fn, drop_remainder, collate_fn_args, label_cols, prefetch, num_workers, num_test_batches)
#     450     dataset = self
#     452 # TODO(Matt, QL): deprecate the retention of label_ids and label
# --> 454 output_signature, columns_to_np_types = dataset._get_output_signature(
#     455     dataset,
#     456     collate_fn=collate_fn,
#     457     collate_fn_args=collate_fn_args,
#     458     cols_to_retain=cols_to_retain,
#     459     batch_size=batch_size if drop_remainder else None,
#     460     num_test_batches=num_test_batches,
#     461 )
#     463 if "labels" in output_signature:
#     464     if ("label_ids" in columns or "label" in columns) and "labels" not in columns:
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\datasets\arrow_dataset.py:284, in TensorflowDatasetMixin._get_output_signature(dataset, collate_fn, collate_fn_args, cols_to_retain, batch_size, num_test_batches)
#     282         test_batch = {key: value for key, value in test_batch.items() if key in cols_to_retain}
#     283     test_batch = [{key: value[i] for key, value in test_batch.items()} for i in range(test_batch_size)]
# --> 284     test_batch = collate_fn(test_batch, **collate_fn_args)
#     285     test_batches.append(test_batch)
#     287 tf_columns_to_signatures = {}
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\data\data_collator.py:682, in DataCollatorForSeq2Seq.__call__(self, features, return_tensors)
#     679 non_labels_features = [{k: v for k, v in feature.items() if k != label_name} for feature in features]
#     681 # run through tokenizer without labels to ensure no side effects
# --> 682 batch = pad_without_fast_tokenizer_warning(
#     683     self.tokenizer,
#     684     non_labels_features,
#     685     padding=self.padding,
#     686     max_length=self.max_length,
#     687     pad_to_multiple_of=self.pad_to_multiple_of,
#     688     return_tensors=return_tensors,
#     689 )
#     691 # we have to pad the labels manually as we cannot rely on `tokenizer.pad` and we need them to be of the same length to return tensors
#     692 no_padding = self.padding is False or self.padding == PaddingStrategy.DO_NOT_PAD
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\data\data_collator.py:66, in pad_without_fast_tokenizer_warning(tokenizer, *pad_args, **pad_kwargs)
#      63 tokenizer.deprecation_warnings["Asking-to-pad-a-fast-tokenizer"] = True
#      65 try:
# ---> 66     padded = tokenizer.pad(*pad_args, **pad_kwargs)
#      67 finally:
#      68     # Restore the state of the warning.
#      69     tokenizer.deprecation_warnings["Asking-to-pad-a-fast-tokenizer"] = warning_state
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\tokenization_utils_base.py:3397, in PreTrainedTokenizerBase.pad(self, encoded_inputs, padding, max_length, pad_to_multiple_of, padding_side, return_attention_mask, return_tensors, verbose)
#    3394             batch_outputs[key] = []
#    3395         batch_outputs[key].append(value)
# -> 3397 return BatchEncoding(batch_outputs, tensor_type=return_tensors)
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\tokenization_utils_base.py:241, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     237     n_sequences = encoding[0].n_sequences
#     239 self._n_sequences = n_sequences
# --> 241 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\tokenization_utils_base.py:731, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     729 elif tensor_type == TensorType.PYTORCH:
#     730     if not is_torch_available():
# --> 731         raise ImportError("Unable to convert output to PyTorch tensors format, PyTorch is not installed.")
#     732     import torch
#     734     is_tensor = torch.is_tensor
#
# ImportError: Unable to convert output to PyTorch tensors format, PyTorch is not installed.

# %%
from sklearn.preprocessing import LabelEncoder

answers = [item['answers'] for item in ds['train']]

# Convert answers to labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(answers)

# Print the mapping of labels
print(dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))))
# Out:
# {np.str_(' 220,000 deaths'): np.int64(0), np.str_(' 4 inches'): np.int64(1), np.str_(' 50% within one week'): np.int64(2), np.str_(' 81% of electricity'): np.int64(3), np.str_(' 90 days'): np.int64(4), np.str_(' Adequate irrigation, especially during dry periods, can help to prevent premature drying of cassava plants.'): np.int64(5), np.str_(' Applying mulch, such as crop residues, grass clippings, or organic materials, on the soil surface helps to protect the soil from erosion by reducing the impact of raindrops and improving water infiltration. Mulch also helps to retain moisture and suppress weed growth.'): np.int64(6), np.str_(' Appropriate spacing makes it easier to access and maintain individual bean plants. This includes activities like weeding, applying fertilizers or pesticides, and inspecting for pests or diseases. Sufficient space between plants allows for better maneuverability and reduces the risk of damaging neighboring plants during maintenance tasks.'): np.int64(7), np.str_(' Artificial fertilizers primarily provide nutrients without adding organic matter to the soil. This can lead to a decrease in organic matter content over time, affecting soil structure, water-holding capacity, and nutrient cycling.'): np.int64(8), np.str_(' As such, there may not be a single entity or group of traders who can be considered the leading bean traders in Uganda.Which district are you interested in?'): np.int64(9), np.str_(' Asia and Latin America'): np.int64(10), np.str_(' Boiling maize grains does not significantly affect the carbohydrate content, so the length of time for boiling is not critical for this nutrient.'): np.int64(11), np.str_(' Chemical (pesticides), biological (biocontrol), mechanical (tillage), and cultural practices are used'): np.int64(12), np.str_(' Crop protection refers to the various methods used to protect crops from pests, diseases, and other threats'): np.int64(13), np.str_(' Dried seeds are easier to handle, store, and transport compared to seeds with higher moisture content. Lower moisture levels reduce the likelihood of seed clumping, mold formation, and damage during storage. Dry seeds also tend to have better flowability, making it easier to measure, package, and distribute them.'): np.int64(14), np.str_(' Drying seeds effectively reduces the risk of spoilage during storage. Moisture provides a favorable environment for the growth of microorganisms, such as fungi and bacteria, which can attack and damage seeds. By reducing moisture content through drying, farmers can inhibit the growth of these organisms and minimize the risk of seed spoilage and loss.'): np.int64(15), np.str_(' Eggs, Larvae, Pupae and Adult'): np.int64(16), np.str_(' Excessive irrigation or heavy rainfall can result in waterlogged soil, leading to the absorption of excess water by the bean plants. This excess water can accumulate in the pods, causing them to become water-filled.'): np.int64(17), np.str_(' FYM improves soil aggregation and creates pore spaces in the soil. This enhanced soil structure helps to create a sponge-like environment that can hold and store moisture for plant use. The organic matter in FYM also acts as a binding agent, preventing soil particles from compacting and reducing the risk of waterlogging.'): np.int64(18), np.str_(' FYM improves soil permeability and enhances water infiltration into the soil. The organic matter in FYM improves soil structure, creating larger pore spaces that allow water to penetrate more easily into the soil rather than running off the surface.'): np.int64(19), np.str_(' Farm yard manure is rich in organic matter, which improves soil structure and promotes aggregation. Organic matter helps to bind soil particles together, creating pore spaces and improving soil porosity. This allows for better air and water movement in the soil, leading to improved soil structure and less compacted soil.\n'): np.int64(20), np.str_(' Farmers and ranchers value wildlife conservation and are working  ...

# %%
# Predict categories / a label

def predict_category(question):
    inputs = tokenizer(question, return_tensors="tf")
    output = model.generate(**inputs)
    response_text = tokenizer.decode(output[0], skip_special_tokens=True)

    # Convert chatbot's response into a category
    if response_text in label_encoder.classes_:
        predicted_label = label_encoder.transform([response_text])[0]
    else:
        predicted_label = -1  # Unknown response
    return predicted_label

# %%
from sklearn.metrics import f1_score

# Generate predictions
true_labels = labels[:100]  # Use a subset for evaluation
predicted_labels = [predict_category(q) for q in ds["train"][:100]["question"]]

# Remove unknown (-1) predictions before scoring
filtered_true_labels = []
filtered_predicted_labels = []
for t, p in zip(true_labels, predicted_labels):
    if p != -1:
        filtered_true_labels.append(t)
        filtered_predicted_labels.append(p)

# Calculate F1-score
f1 = f1_score(filtered_true_labels, filtered_predicted_labels, average='weighted')
print("F1 Score:", f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 5
#       3 # Generate predictions
#       4 true_labels = labels[:100]  # Use a subset for evaluation
# ----> 5 predicted_labels = [predict_category(q) for q in ds["train"][:100]["question"]]
#       7 # Remove unknown (-1) predictions before scoring
#       8 filtered_true_labels = []
#
# Cell In[61], line 5, in <listcomp>(.0)
#       3 # Generate predictions
#       4 true_labels = labels[:100]  # Use a subset for evaluation
# ----> 5 predicted_labels = [predict_category(q) for q in ds["train"][:100]["question"]]
#       7 # Remove unknown (-1) predictions before scoring
#       8 filtered_true_labels = []
#
# Cell In[59], line 5, in predict_category(question)
#       3 def predict_category(question):
#       4     inputs = tokenizer(question, return_tensors="tf")
# ----> 5     output = model.generate(**inputs)
#       6     response_text = tokenizer.decode(output[0], skip_special_tokens=True)
#       8     # Convert chatbot's response into a category
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\generation\tf_utils.py:739, in TFGenerationMixin.generate(self, inputs, generation_config, logits_processor, seed, **kwargs)
#     737 generation_config = copy.deepcopy(generation_config)
#     738 model_kwargs = generation_config.update(**kwargs)  # All unused kwargs must be model kwargs
# --> 739 self._validate_model_kwargs(model_kwargs.copy())
#     741 # 2. Cast input dtypes to tf.int32 unless they're floats (which happens for some image models)
#     742 if inputs is not None:
#
# File c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\generation\tf_utils.py:640, in TFGenerationMixin._validate_model_kwargs(self, model_kwargs)
#     637         unused_model_args.append(key)
#     639 if unused_model_args:
# --> 640     raise ValueError(
#     641         f"The following `model_kwargs` are not used by the model: {unused_model_args} (note: typos in the"
#     642         " generate arguments will also show up in this list)"
#     643     )
#
# ValueError: The following `model_kwargs` are not used by the model: ['token_type_ids'] (note: typos in the generate arguments will also show up in this list)

# %%
# Evaluate the model with BLEW

from datasets import load_metric

metric = load_metric("bleu")

# Example evaluation function
def evaluate_model(question):
    inputs = tokenizer(question, return_tensors="tf")
    output = model.generate(**inputs)
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

sample_question = "What are the best fertilizers for wheat?"
print(evaluate_model(sample_question))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 3
#       1 # Evaluate the model with BLEW
# ----> 3 from datasets import load_metric
#       5 metric = load_metric("bleu")
#       7 # Example evaluation function
#
# ImportError: cannot import name 'load_metric' from 'datasets' (c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\datasets\__init__.py)

# %%
import gradio as gr

def chatbot_response(question):
    return evaluate_model(question)

iface = gr.Interface(fn=chatbot_response, inputs="text", outputs="text", title="Agriculture Chatbot")
iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\gradio\queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\gradio\blocks.py", line 2096, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\gradio\blocks.py", line 1643, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\gradio\utils.py", line 883, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\yiish\AppData\Local\Temp\ipykernel_16040\1562740712.py", line 4, in chatbot_response
#     return evaluate_model(question)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\yiish\AppData\Local\Temp\ipykernel_16040\1719972774.py", line 7, in evaluate_model
#     output = model.generate(**inputs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\generation\tf_utils.py", line 739, in generate
#     self._validate_model_kwargs(model_kwargs.copy())
#   File "c:\Users\yiish\OneDrive\Desktop\domain-chatbot\new-venv\Lib\site-packages\transformers\generation\tf_utils.py", line 640, in _validate_model_kwargs
#     raise ValueError(
# ValueError: The following `model_kwargs` are not used by the model: ['token_type_ids'] (note: typos in the generate arguments will also show up in this list)
